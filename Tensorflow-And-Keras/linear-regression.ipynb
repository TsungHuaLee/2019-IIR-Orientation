# %%
import numpy as np
import matplotlib.pyplot as plt
from contextlib import contextmanager

# %%
np.random.seed(0)
# target function y = 3 * x + 5
ori_a = np.full((10), 3)
ori_b = 5
ori_x = np.linspace(1, 10 ,10)
ori_y = ori_a * ori_x + ori_b

# setting y point
tar_y = ori_a * ori_x + ori_b + np.random.randn(10) * 2

# setting random W
wei = np.full((10), np.random.rand(1)*10)
bias = np.random.rand(1)*10

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.grid(True)
plt.plot(ori_x, ori_y, 'bo')
plt.plot(ori_x, ori_y)

new_y = wei * ori_x + bias

plt.plot(ori_x, tar_y, 'ro')
plt.plot(ori_x, new_y)

# %%
def gradient_descent(x, y, wei, bias, lr):
    n = x.size
    wei_slope = np.sum((y - wei * x - bias) * x / n)
    wei = wei - lr * wei_slope
    bias_slope = np.sum(y - wei * x - bias)/n
    bias = bias - lr * bias_slope
    
    return wei, bias

for i in range(epoch)
    wei, bias = gradient_descent(ori_x, tar_y, wei, bias, 0.01)

plt.plot(ori_x, ori_y, 'bo')
plt.plot(ori_x, ori_y)

new_y = wei * ori_x + bias
plt.plot(ori_x, tar_y, 'ro')
plt.plot(ori_x, new_y)
# Out:
# [2.13152539 2.13152539 2.13152539 2.13152539 2.13152539 2.13152539
#  2.13152539 2.13152539 2.13152539 2.13152539] 4.784311278888402
